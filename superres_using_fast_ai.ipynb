# %% [markdown]
# ## Super resolution

# %%
import fastai
from fastai.vision import *
from fastai.callbacks import *
from fastai.utils.mem import *

from torchvision.models import vgg16_bn
import glob, shutil

# %%
# path = untar_data(URLs.PETS)
# path_hr = path/'images'
# path_lr = path/'small-96'
# path_mr = path/'small-256'

# %%
path = untar_data(URLs.IMAGENETTE_320)

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/imagenette2-320/train'),
#  PosixPath('/root/.fastai/data/imagenette2-320/val')]

# %%
# !mkdir /root/.fastai/data/imagenette2-320/"all_images"

# %%
path.ls()
# ! ls '/root/.fastai/data/cifar10/test'
# Out:
# [PosixPath('/root/.fastai/data/imagenette2-320/train'),
#  PosixPath('/root/.fastai/data/imagenette2-320/all_images'),
#  PosixPath('/root/.fastai/data/imagenette2-320/val')]

# %%
for i in (path/'train').ls():
  for file in glob.glob(str(i) + '/' + '*.JPEG'):
    shutil.move(file, path/'all_images')

# %%
for i in (path/'val').ls():
  for file in glob.glob(str(i) + '/' + '*.JPEG'):
    shutil.move(file, path/'all_images')

# %%
len((path/"all_images").ls())
# Out:
# 13394

# %%
# path = untar_data(URLs.CIFAR)
path_hr = path/'all_images'
path_lr = path/'small-96'
path_mr = path/'small-256'

# %%
# path_hr.ls()

# %%
il = ImageList.from_folder(path_hr)

# %%
# # il?
# plt.show(il.items[0:10])

# %%
def resize_one(fn, i, path, size):
    # print("work")
    dest = path/fn.relative_to(path_hr)
    dest.parent.mkdir(parents=True, exist_ok=True)
    img = PIL.Image.open(fn)
    targ_sz = resize_to(img, size, use_min=True)
    img = img.resize(targ_sz, resample=PIL.Image.BILINEAR).convert('RGB')
    img.save(dest, quality=60)

# %%
# create smaller image sets the first time this nb is run
sets = [(path_lr, 96), (path_mr, 256)]
for p,size in sets:
    if not p.exists(): 
        print(f"resizing to {size} into {p}")
        parallel(partial(resize_one, path=p, size=size), il.items)
# Out:
# resizing to 96 into /root/.fastai/data/imagenette2-320/small-96
# resizing to 256 into /root/.fastai/data/imagenette2-320/small-256

# %%
# !rm -rf /root/.fastai/data/imagenette2-320/train
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/imagenette2-320/small-256'),
#  PosixPath('/root/.fastai/data/imagenette2-320/all_images'),
#  PosixPath('/root/.fastai/data/imagenette2-320/small-96'),
#  PosixPath('/root/.fastai/data/imagenette2-320/val')]

# %%
# !rm -rf /root/.fastai/data/imagenette2-320/val
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/imagenette2-320/small-256'),
#  PosixPath('/root/.fastai/data/imagenette2-320/all_images'),
#  PosixPath('/root/.fastai/data/imagenette2-320/small-96')]

# %%
len(path_hr.ls()), len(path_lr.ls()), len(path_mr.ls())
# Out:
# (13394, 13394, 13394)

# %%
bs,size=16,128
arch = models.resnet34

src = ImageImageList.from_folder(path_lr).split_by_rand_pct(0.1, seed=42)

# %%
src #contains image of low resolution
# Out:
# ItemLists;
#
# Train: ImageImageList (12055 items)
# Image (3, 96, 96),Image (3, 96, 144),Image (3, 96, 315),Image (3, 108, 96),Image (3, 96, 131)
# Path: /root/.fastai/data/imagenette2-320/small-96;
#
# Valid: ImageImageList (1339 items)
# Image (3, 96, 127),Image (3, 96, 127),Image (3, 124, 96),Image (3, 146, 96),Image (3, 96, 257)
# Path: /root/.fastai/data/imagenette2-320/small-96;
#
# Test: None

# %%
def get_data(bs,size):
    data = (src.label_from_func(lambda x: path_hr/x.name)
           .transform(get_transforms(max_zoom=2.), size=size, tfm_y=True)
           .databunch(bs=bs).normalize(imagenet_stats, do_y=True))

    data.c = 3
    return data

# %%
data = get_data(bs,size)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (12055 items)
# x: ImageImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# Path: /root/.fastai/data/imagenette2-320/small-96;
#
# Valid: LabelList (1339 items)
# x: ImageImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# Path: /root/.fastai/data/imagenette2-320/small-96;
#
# Test: None

# %%
data.show_batch(ds_type=DatasetType.Valid, rows=2, figsize=(9,9))

# %% [markdown]
# ## Feature loss

# %%
t = data.valid_ds[0][1].data
t = torch.stack([t,t])

# %%
def gram_matrix(x):
    n,c,h,w = x.size()
    x = x.view(n, c, -1)
    return (x @ x.transpose(1,2))/(c*h*w)

# %%
gram_matrix(t)
# Out:
# tensor([[[0.0849, 0.0883, 0.0926],
#          [0.0883, 0.0922, 0.0970],
#          [0.0926, 0.0970, 0.1027]],
#
#         [[0.0849, 0.0883, 0.0926],
#          [0.0883, 0.0922, 0.0970],
#          [0.0926, 0.0970, 0.1027]]])

# %%
base_loss = F.l1_loss

# %%
vgg_m = vgg16_bn(True).features.cuda().eval()
requires_grad(vgg_m, False)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/checkpoints/vgg16_bn-6c64b313.pth
# ...

# %%
blocks = [i-1 for i,o in enumerate(children(vgg_m)) if isinstance(o,nn.MaxPool2d)]
blocks, [vgg_m[i] for i in blocks]
# Out:
# ([5, 12, 22, 32, 42],
#  [ReLU(inplace=True),
#   ReLU(inplace=True),
#   ReLU(inplace=True),
#   ReLU(inplace=True),
#   ReLU(inplace=True)])

# %%
class FeatureLoss(nn.Module):
    def __init__(self, m_feat, layer_ids, layer_wgts):
        super().__init__()
        self.m_feat = m_feat
        self.loss_features = [self.m_feat[i] for i in layer_ids]
        self.hooks = hook_outputs(self.loss_features, detach=False)
        self.wgts = layer_wgts
        self.metric_names = ['pixel',] + [f'feat_{i}' for i in range(len(layer_ids))
              ] + [f'gram_{i}' for i in range(len(layer_ids))]

    def make_features(self, x, clone=False):
        self.m_feat(x)
        return [(o.clone() if clone else o) for o in self.hooks.stored]
    
    def forward(self, input, target):
        out_feat = self.make_features(target, clone=True)
        in_feat = self.make_features(input)
        self.feat_losses = [base_loss(input,target)]
        self.feat_losses += [base_loss(f_in, f_out)*w
                             for f_in, f_out, w in zip(in_feat, out_feat, self.wgts)]
        self.feat_losses += [base_loss(gram_matrix(f_in), gram_matrix(f_out))*w**2 * 5e3
                             for f_in, f_out, w in zip(in_feat, out_feat, self.wgts)]
        self.metrics = dict(zip(self.metric_names, self.feat_losses))
        return sum(self.feat_losses)
    
    def __del__(self): self.hooks.remove()

# %%
feat_loss = FeatureLoss(vgg_m, blocks[2:5], [5,15,2])

# %% [markdown]
# ## Train

# %%
wd = 1e-3
learn = unet_learner(data, arch, wd=wd, loss_func=feat_loss, callback_fns=LossMetrics,
                     blur=True, norm_type=NormType.Weight)
gc.collect();
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel</th>
#       <th>feat_0</th>
#       <th>feat_1</th>
#       <th>feat_2</th>
#       <th>gram_0</th>
# ...

# %%
lr = 1e-3

# %%
def do_fit(save_name, lrs=slice(lr), pct_start=0.9):
    learn.fit_one_cycle(10, lrs, pct_start=pct_start)
    learn.save(save_name)
    learn.show_results(rows=1, imgsize=5)

# %%
do_fit('1a', slice(lr*10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel</th>
#       <th>feat_0</th>
#       <th>feat_1</th>
#       <th>feat_2</th>
#       <th>gram_0</th>
#       <th>gram_1</th>
#       <th>gram_2</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.099929</td>
#       <td>2.933775</td>
#       <td>0.165498</td>
#       <td>0.219323</td>
#       <td>0.278663</td>
#       <td>0.162558</td>
#       <td>0.496447</td>
#       <td>0.976860</td>
#       <td>0.634426</td>
#       <td>03:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.045744</td>
#       <td>2.882734</td>
#       <td>0.165594</td>
#       <td>0.216505</td>
#       <td>0.274613</td>
#       <td>0.159104</td>
#       <td>0.481401</td>
#       <td>0.968836</td>
#       <td>0.616682</td>
#       <td>03:45</td>
#     </tr>
# ...

# %%
learn.unfreeze()

# %%
# gc.collect();

# %%
do_fit('1b', slice(1e-5,lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel</th>
#       <th>feat_0</th>
#       <th>feat_1</th>
#       <th>feat_2</th>
#       <th>gram_0</th>
#       <th>gram_1</th>
#       <th>gram_2</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.710469</td>
#       <td>2.533378</td>
#       <td>0.156279</td>
#       <td>0.204383</td>
#       <td>0.250441</td>
#       <td>0.141713</td>
#       <td>0.392134</td>
#       <td>0.840261</td>
#       <td>0.548167</td>
#       <td>03:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.702856</td>
#       <td>2.530323</td>
#       <td>0.156123</td>
#       <td>0.204176</td>
#       <td>0.250152</td>
#       <td>0.141597</td>
#       <td>0.391285</td>
#       <td>0.839109</td>
#       <td>0.547881</td>
#       <td>03:53</td>
#     </tr>
# ...

# %%
data = get_data(12,size*2)

# %%
learn.data = data
learn.freeze()
gc.collect()
# Out:
# 15754

# %%
learn.load('1b');

# %%
do_fit('2a')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel</th>
#       <th>feat_0</th>
#       <th>feat_1</th>
#       <th>feat_2</th>
#       <th>gram_0</th>
#       <th>gram_1</th>
#       <th>gram_2</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.986934</td>
#       <td>1.902720</td>
#       <td>0.171751</td>
#       <td>0.246829</td>
#       <td>0.268466</td>
#       <td>0.121555</td>
#       <td>0.331077</td>
#       <td>0.502532</td>
#       <td>0.260509</td>
#       <td>08:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.958149</td>
#       <td>1.889241</td>
#       <td>0.172250</td>
#       <td>0.246896</td>
#       <td>0.267515</td>
#       <td>0.121384</td>
#       <td>0.325070</td>
#       <td>0.497531</td>
#       <td>0.258593</td>
#       <td>08:37</td>
#     </tr>
# ...

# %%
learn.unfreeze()

# %%
do_fit('2b', slice(1e-6,1e-4), pct_start=0.3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pixel</th>
#       <th>feat_0</th>
#       <th>feat_1</th>
#       <th>feat_2</th>
#       <th>gram_0</th>
#       <th>gram_1</th>
#       <th>gram_2</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.860777</td>
#       <td>1.809839</td>
#       <td>0.169949</td>
#       <td>0.242845</td>
#       <td>0.259897</td>
#       <td>0.118309</td>
#       <td>0.291703</td>
#       <td>0.475471</td>
#       <td>0.251663</td>
#       <td>08:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.851540</td>
#       <td>1.809678</td>
#       <td>0.170676</td>
#       <td>0.242968</td>
#       <td>0.259716</td>
#       <td>0.118053</td>
#       <td>0.292053</td>
#       <td>0.475076</td>
#       <td>0.251136</td>
#       <td>08:53</td>
#     </tr>
# ...

# %% [markdown]
# ## Test

# %%
learn = None
gc.collect();

# %%
256/320*1024
# Out:
# 819.2

# %%
256/320*1600
# Out:
# 1280.0

# %%
free = gpu_mem_get_free_no_cache()
# the max size of the test image depends on the available GPU RAM 
if free > 8000: size=(1280, 1600) # >  8GB RAM
else:           size=( 820, 1024) # <= 8GB RAM
print(f"using size={size}, have {free}MB of GPU RAM free")
# Out:
# using size=(1280, 1600), have 14731MB of GPU RAM free

# %%
learn = unet_learner(data, arch, loss_func=F.l1_loss, blur=True, norm_type=NormType.Weight)

# %%
data_mr = (ImageImageList.from_folder(path_mr).split_by_rand_pct(0.1, seed=42)
          .label_from_func(lambda x: path_hr/x.name)
          .transform(get_transforms(), size=size, tfm_y=True)
          .databunch(bs=1).normalize(imagenet_stats, do_y=True))
data_mr.c = 3

# %%
learn.load('2b');

# %%
learn.data = data_mr

# %%
fn = data_mr.valid_ds.x.items[0]; fn
# Out:
# PosixPath('/root/.fastai/data/imagenette2-320/small-256/n02102040_3176.JPEG')

# %%
img = open_image(fn); img.shape
# Out:
# torch.Size([3, 340, 256])

# %%
p,img_hr,b = learn.predict(img)

# %%
show_image(img, figsize=(18,15), interpolation='nearest');

# %%
Image(img_hr).show(figsize=(18,15))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
